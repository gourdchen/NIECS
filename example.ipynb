# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from view import nilearn_view

# %%
import numpy as np
import nibabel as nib

# %%
template_data = np.zeros([2562,2])
for i,hemi in enumerate(['lh','rh']):
    for net_n in range(1,20):
        data = nib.load("../pin_ind_net/Plos_ref/HFR_ai/Templates/Parcellation_template/{}_network_{}_asym_fs4.mgh".format(hemi,net_n)).get_fdata().squeeze()
        template_data[data > 0, i] = net_n-1

# %%
template_data.shape
# Out:
# (2562, 2)

# %%
res  = nilearn_view.plot_surf_nilearn_single(left_data=template_data[:,0],right_data=template_data[:,1],surf_type='inflated')

# %%
res  = nilearn_view.plot_surf_nilearn_row(left_data=template_data[:,0],right_data=template_data[:,1])
